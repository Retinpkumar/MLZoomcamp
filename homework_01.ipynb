# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Q1. Pandas version

# %%
pd.__version__
# Out:
# '3.0.6'

# %% [markdown]
# ### Q2. Records count

# %%
data = pd.read_csv('data/car_fuel_efficiency_2026.csv')
df = data.copy()

# Total records
total_records = len(df)
print(total_records)
# Out:
# 10000

# %%
df.head(5)
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# ### Q3. Fuel types

# %%
# Find fuel types
fuel_types = df['fuel_type'].unique().tolist()
print(fuel_types)
# Out:
# ['Gasoline', 'Diesel', 'Hybrid']

# %% [markdown]
# ### Q4. Missing values

# %%
# Find missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# ### Q5. Max fuel efficiency

# %%
# Max fuel efficiency
max_fuel_efficiency = df['fuel_efficiency_mpg'].max()
print(max_fuel_efficiency)
# Out:
# 41.2

# %% [markdown]
# ### Q6. Median value of horsepower

# %%
# Median value of horse power
median_horse_power = df['horsepower'].median()
print(median_horse_power)
# Out:
# 254.0

# %%
# Most frequent value of horse power
most_frequent_horse_power = df['horsepower'].mode()[0]
print(most_frequent_horse_power)
# Out:
# 252.0

# %%
# Filling missing values in horsepower with most frequent value
df['horsepower'] = df['horsepower'].fillna(most_frequent_horse_power)

# %%
# Median value of horse power
median_horse_power = df['horsepower'].median()
print(median_horse_power)
# Out:
# 252.0

# %% [markdown]
# ### Q7. Sum of weights

# %%
# Select all the cars from Asia
df_asia = df[df['origin'] == 'Asia']

# %%
# Select only columns vehicle_weight and model_year
df_selected = df_asia[['vehicle_weight', 'model_year']]

# %%
# Select the first 7 values
first_seven_values = df_selected.head(7)

# %%
# Get the underlying NumPy array. Let's call it X.
x = first_seven_values.values
print(x)
# Out:
# [[4240 1996]
#  [4310 1992]
#  [4230 1997]
#  [4420 1978]
#  [3950 2007]
#  [4750 2021]
#  [4450 2019]]

# %%
# Compute matrix-matrix multiplication between the transpose of X and X
X_transpose_X = x.T @ x
print(X_transpose_X)
# Out:
# [[131950500  60750580]
#  [ 60750580  28041424]]

# %%
# Invert XTX
XTX_inverse = np.linalg.inv(X_transpose_X)
print(XTX_inverse)
# Out:
# [[ 2.96830537e-06 -6.43071025e-06]
#  [-6.43071025e-06  1.39675281e-05]]

# %%
# Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200]
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
print(y)
# Out:
# [1100 1300  800  900 1000 1100 1200]

# %%
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
res1 = XTX_inverse @ x.T
w = res1 @ y
print(w)
# Out:
# [0.13644777 0.2327492 ]

# %%
# Sum of all the elements of the result
sum_w = np.sum(w)
print(sum_w)
# Out:
# 0.36919696904925486
